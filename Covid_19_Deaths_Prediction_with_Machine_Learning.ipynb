# %% [markdown]
# <a href="https://colab.research.google.com/github/Howida100/Simple-Project-/blob/main/Covid_19_Deaths_Prediction_with_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# the dataset contain the following columns :
# Date: Contains the date of the record
# Date_YMD: Contains date in Year-Month-Day Format
# Daily Confirmed: Contains the daily confirmed cases of Covid-19
# Daily Deceased: Contains the daily deaths due to Covid-19 **bold text** *italicized text*

# %%
import pandas as pd
import numpy as np
data = pd.read_csv("/raw.githubusercontent.com_amankharwal_Website-data_master_COVID19 data for overall INDIA.csv")
print(data.head())
# Out:
#         Date   Date_YMD  Daily Confirmed  Daily Deceased
# 0  30-Jan-20  30/1/2020                1               0
# 1  31-Jan-20  31/1/2020                0               0
# 2   1-Feb-20   1/2/2020                0               0
# 3   2-Feb-20   2/2/2020                1               0
# 4   3-Feb-20   3/2/2020                1               0

# %%
data.isnull().sum()
# Out:
# Date               0
# Date_YMD           0
# Daily Confirmed    0
# Daily Deceased     0
# dtype: int64

# %%
data = data.drop("Date", axis=1)

# %%
data
# Out:
#       Date_YMD  Daily Confirmed  Daily Deceased
# 0    30/1/2020                1               0
# 1    31/1/2020                0               0
# 2     1/2/2020                0               0
# 3     2/2/2020                1               0
# 4     3/2/2020                1               0
# ..         ...              ...             ...
# 715  14/1/2022           266518             621
# 716  15/1/2022           271202             314
# 717  16/1/2022           258089             385
# 718  17/1/2022           238018             310
# 719  18/1/2022           282970             441
#
# [720 rows x 3 columns]

# %%
import plotly.express as px
fig = px.bar(data, x='Date_YMD', y='Daily Confirmed')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# visualize the death rate due to Covid-19:

# %%
cases = data["Daily Confirmed"].sum()
deceased = data["Daily Deceased"].sum()

labels = ["Confirmed", "Deceased"]
values = [cases, deceased]

fig = px.pie(data, values=values,
             names=labels,
             title='Daily Confirmed Cases vs Daily Deaths', hole=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# calculate the death rate of Covid-19:

# %%
death_rate = (data["Daily Deceased"].sum() / data["Daily Confirmed"].sum()) * 100
print(death_rate)
# Out:
# 1.2840580507834722

# %% [markdown]
# daily deaths of covid-19:

# %%
import plotly.express as px
fig = px.bar(data, x='Date_YMD', y='Daily Deceased')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# !pip install matplotlib-venn

# %% [markdown]
# **Covid-19 Deaths Prediction Model**

# %%
# !pip install autots
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 765.3/765.3 kB 4.8 MB/s eta 0:00:00
# ...
